# %%
# ==========================================
# 🐧 DOCKER CHEAT SHEET PARA MICROSERVICIOS 🐧
# ==========================================

"""
1. INICIO Y CONSTRUCCIÓN (Orquestación)
--------------------------------------
"""
# Levantar todo el sistema en segundo plano
# docker compose up -d

# RECONSTRUIR cambios en el código y levantar (Obligatorio tras editar .py)
# docker compose up -d --build

# Levantar un solo servicio específico (ej: solo el de logs)
# docker compose up -d --build logs_service


"""
2. DETENCIÓN Y LIMPIEZA
--------------------------------------
"""
# Detener y BORRAR contenedores y redes (Limpieza total)
# docker compose down

# Detener sin borrar (Mantiene el estado)
# docker compose stop

# Borrar TODAS las imágenes, contenedores y redes que no se usen (Deep Clean)
# docker system prune -f


"""
3. INSPECCIÓN Y DEPURACIÓN (Debugging)
--------------------------------------
"""
# Ver el estado de todos los servicios (¿Están en UP o EXIT?)
# docker compose ps

# Ver logs en tiempo real de un servicio para encontrar errores de Python
# docker compose logs -f account_service

# Entrar a la consola de una base de datos específica
# docker exec -it db_auth psql -U admin -d auth_db


"""
4. BASE DE DATOS (Mantenimiento)
--------------------------------------
"""
# Si la base de datos se corrompe o quieres resetear saldos:
# docker compose down -v  <-- El -v borra los volúmenes (los datos guardados)
